# %% [markdown]
# Capstone Project - The Battle of Neighborhoods
# Background
# There is a close relationship between China and Hong Kong. The medical system in Hong Kong is still relatively advanced and therefore it is appealing for middle-class people in China to stay in Hong Kong for medication.
# Objective
# From the locations of the clinics in Hong Kong, we have to explore the nearby locations and classify as different useful categories for tourists in order for them to decide to stay in nearby hotels for the convenience of medication.
# The Hong Kong Government currently provides open data with geospatial information for easier manipulation. And the FourSquare API is useful to explore the nearby locations.
#
# A recommendation summary is provided at the end of the notebook

# %%
import pandas as pd
import numpy as np # library to handle data in a vectorized manner

import requests

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
#=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     certifi-2019.3.9           |           py36_0         149 KB  conda-forge
#     conda-4.6.8                |           py36_0         876 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.18.1               |             py_0          51 KB  conda-forge
#     openssl-1.1.1b             |       h14c3975_1         4.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2018.11.29-ha4d7672_0 --> 2019.3.9-hecc5488_0
#   certifi                              2018.11.29-py36_1000 --> 2019.3.9-py36_0
#   conda                                        4.6.4-py36_0 --> 4.6.8-py36_0
#   geopy              conda-forge/linux-64::geopy-1.11.0-py~ --> conda-forge/noarch::geopy-1.18.1-py_0
#   openssl                              1.1.1a-h14c3975_1000 --> 1.1.1b-h14c3975_1
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# openssl-1.1.1b       | 4.0 MB    | ##################################### | 100%
# conda-4.6.8          | 876 KB    | ##################################### | 100%
# geopy-1.18.1         | 51 KB     | ##################################### | 100%
# certifi-2019.3.9     | 149 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata: done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
#Open data from Hong Kong Government. Excel is provided
ClinicData = "http://www.dh.gov.hk/datagovhk/Clinic_under_Cap343.xlsx"

# %%
#Read Excel and drop irrelevant rows
df_clinic = pd.read_excel(ClinicData,skiprows=1)
df_clinic = df_clinic.drop(df_clinic.columns[[0]], axis=1)
df_clinic = df_clinic.drop([1,6,69,70,89], axis=0)
df_clinic = df_clinic.reset_index()
df_clinic = df_clinic.drop(['index'], axis=1)
df_clinic
# Out:
#                                        Name of Clinic  \
# 0                    Assemblies of God Medical Clinic
# 1                          BOCHK Health Care Division
# 2                         Caritas Clinic – Caine Road
# 3                       Caritas Clinic – Ngau Tau Kok
# 4                Caritas Jockey Club Tsuen Wan Clinic
# 5                      Centre of Wellness (Kwun Tong)
# 6                              Chee Kwong Free Clinic
# 7                            Ching Chung No. 2 Clinic
# 8      Christian Family Service Centre Medical Clinic
# 9                   Clinic of China Resources Company
# 10                           Emmanuel Medical Mission
# 64  Area A, 1/F, Cheerful Court, 55 Choi Ha Road, ...  22.325700  114.216241
# 65    13/F, Sino Cheer Plaza, 23 Jordan Road, Kowloon  22.305528  114.170823
# 66  University Health Service, The Hong Kong Polyt...  22.303216  114.177905
# 67  Flat C, 1/F, 379 Lockhart Road, Wan Chai, Hong...  22.279655  114.179681
# 68                    1/F, 6 Portland Street, Kowloon  22.312082  114.170372
# 69  Room 6A, 6/F, Toi Shan Centre, 128 Johnston Ro...  22.276484  114.173477
# 70  1/F, 32A Belcher's Street, Kennedy Town, Hong ...  22.283021  114.130119
# 71  Room 303, 1/F, Kam Yuck Building, Wai Chi Lane...  22.334513  114.167206
# 72      G/F, 36 Yin Hing Street, San Po Kong, Kowloon  22.335621  114.194646
# 73  1/F, 100 Chung On Street, Tsuen Wan, New Terri...  22.369403  114.116669
# 74  1/F, 89 Tai Hong Wai, Kam Tin Main Road, Kam T...  22.440965  114.064746
# 75  Shop E, G/F, Man On Building, 2-6 Man On Stree...  22.323448  114.161528
# 76  Shop I1 & I2, G/F, Tak Tai Building, 19B Tai H...  22.369043  114.123187
# 77         G/F, 16 Waterloo Road, Yau Ma Tei, Kowloon  22.312763  114.169709
# 78  G/F, 30 Shung Wah Street, Fung Wong Village, K...  22.346347  114.198123
# 79      G/F, 75 First Street, Sai Ying Pun, Hong Kong  22.286704  114.141975
# 80  Room 204, 2/F, Chung Wo Commercial Centre, 42-...  22.304223  114.169318
# 81  M/F, 99 Kwong Fuk Road, Tai Po Market, New Ter...  22.448552  114.167724
# 82  No. 4, G/F, Lung Lok House, Wong Tai Sin Lower...  22.341206  114.192567
# 83  Flat B, 1/F, Hong Ning Mansion, 56-58 Nga Tsin...  22.329097  114.190661
# 84  Flat J, 2/F, Yen Dack Building, 103 - 113 Chun...  22.291629  114.198324

# %%
print('There are total {} clinics in Hong Kong'.format(df_clinic.shape[0]))
# Out:
# There are total 85 clinics in Hong Kong

# %%
#Find the latitude and longitude of Hong Kong from Nominatim
address = 'Hong Kong'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Hong Kong are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   after removing the cwd from sys.path.
# The geograpical coordinate of Hong Kong are 22.2793278, 114.1628131.

# %%
# set number of clusters
kclusters = 5

X = df_clinic['Latitude']
Y = df_clinic['Longitude']
Z = np.stack((X, Y), axis=1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Z)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 2, 2, 4, 3, 4, 0, 1, 4, 2], dtype=int32)

# %%
# create map
clinic_map = folium.Map(location=[latitude, longitude], zoom_start=11)

colors = ['red', 'orange', 'yellow', 'green', 'blue']
df_clinic['Cluster'] = kmeans.labels_

for lat, long, clinic_name, cluster in zip(df_clinic['Latitude'], df_clinic['Longitude'], df_clinic['Name of Clinic'], df_clinic['Cluster']):
    label = folium.Popup(clinic_name, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=5,
        popup=label,
        color='black',
        fill=True,
        fill_color=colors[cluster],
        fill_opacity=0.7).add_to(clinic_map)  

clinic_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#FourSquare API information
CLIENT_ID = 'UFJR3WSEYX2V0EZGL2DVJ3SIZN05OZ2VTFYG0Z1TSGQIIBQE' # your Foursquare ID
CLIENT_SECRET = 'P52B3Q4ESSJF0BDZW4501M0UBK33JTATA4CQE4IWDITCDNQD' # your Foursquare Secret
VERSION = '20180604'

#Limit to 100 entries
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UFJR3WSEYX2V0EZGL2DVJ3SIZN05OZ2VTFYG0Z1TSGQIIBQE
# CLIENT_SECRET:P52B3Q4ESSJF0BDZW4501M0UBK33JTATA4CQE4IWDITCDNQD

# %%
#Provide a location to explore nearby locations
address = 'Hysan Place, Causeway Bay, Hong Kong'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude1 = location.latitude
longitude1 = location.longitude
print(latitude1, longitude1)
# Out:
# 22.27981135 114.18378509374

# %%
#1000 meters is used as it is a walkable distance for tourists
radius = 1000

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude1, longitude1, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=UFJR3WSEYX2V0EZGL2DVJ3SIZN05OZ2VTFYG0Z1TSGQIIBQE&client_secret=P52B3Q4ESSJF0BDZW4501M0UBK33JTATA4CQE4IWDITCDNQD&ll=22.27981135,114.18378509374&v=20180604&radius=1000&limit=100'

# %%
#Reading results from FourSquare
results = requests.get(url).json()
'There are {} around Clinic location 1'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 100 around Clinic location 1'

# %%
#Understand the first item
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ff44a45f31c307dc1999e9f',
#   'name': 'Eslite Bookstore (誠品書店)',
#   'location': {'address': '8-10/F, Hysan Place, 500 Hennessy Rd',
#    'lat': 22.28024004574223,
#    'lng': 114.18385392453827,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 22.28024004574223,
#      'lng': 114.18385392453827}],
#    'distance': 48,
#    'cc': 'HK',
#    'city': '铜锣湾',
#    'country': '香港',
#    'formattedAddress': ['8-10/F, Hysan Place, 500 Hennessy Rd', '香港']},
#   'categories': [{'id': '4bf58dd8d48988d114951735',
#     'name': 'Bookstore',
#     'pluralName': 'Bookstores',
#     'shortName': 'Bookstore',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4ff44a45f31c307dc1999e9f-0'}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Filter the results with categories in FourSquare
from pandas.io.json import json_normalize

dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                               name            categories  \
# 0          Eslite Bookstore (誠品書店)             Bookstore
# 1               Apple Causeway Bay     Electronics Store
# 2            SOGO Freshmart (崇光超市)           Supermarket
# 3    Kozy Okonomi-yaki Teppan-yaki   Japanese Restaurant
# 4               Din Tai Fung (鼎泰豐)   Dumpling Restaurant
# 5                     UNIQLO (優衣庫)        Clothing Store
# 6                        Pure Yoga           Yoga Studio
# 7                    Café Corridor                  Café
# 8  Yee Shun Dairy Company (義順牛奶公司)        Cha Chaan Teng
# 9                     Pure Fitness  Gym / Fitness Center
#
#                                        address  cc city country crossStreet  \
# 0         8-10/F, Hysan Place, 500 Hennessy Rd  HK  铜锣湾      香港         NaN
# 1                       銅鑼灣軒尼詩道500號, 希慎廣場, 灣仔區  HK  铜锣湾      香港         NaN
# 2                  B2/F, Sogo, 555 Hennessy Rd  HK  铜锣湾      香港         NaN
# 3           9/F, Circle Plaza, 499 Hennessy Rd  HK  铜锣湾      香港         NaN
# 4                                 68 Yee Wo St  HK  铜锣湾      香港         NaN
# 5  B2/F-G/F, Lee Theatre Plaza, 99 Percival St  HK  铜锣湾      香港         NaN
# 6         25/F, Soundwill Plaza, 38 Russell St  HK  铜锣湾      香港         NaN
# 7                          G/F, 26A Russell St  HK  铜锣湾      香港         NaN
# 8                              506 Lockhart Rd  HK  铜锣湾      香港         NaN
# 9      15/F, Lee Theatre Plaza, 99 Percival St  HK  铜锣湾      香港         NaN
#
#    distance                                   formattedAddress  \
# 0        48         [8-10/F, Hysan Place, 500 Hennessy Rd, 香港]
# 1         7                       [銅鑼灣軒尼詩道500號, 希慎廣場, 灣仔區, 香港]
# 2       104                  [B2/F, Sogo, 555 Hennessy Rd, 香港]
# 3        56           [9/F, Circle Plaza, 499 Hennessy Rd, 香港]
# 4       261                                 [68 Yee Wo St, 香港]
# 5       170  [B2/F-G/F, Lee Theatre Plaza, 99 Percival St, 香港]
# 6       174         [25/F, Soundwill Plaza, 38 Russell St, 香港]
# 7       187                          [G/F, 26A Russell St, 香港]
# 8        95                              [506 Lockhart Rd, 香港]
# 9       153      [15/F, Lee Theatre Plaza, 99 Percival St, 香港]
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 22.28024004574223...  22.280240  114.183854
# 1  [{'label': 'display', 'lat': 22.2797509, 'lng'...  22.279751  114.183808
# 2  [{'label': 'display', 'lat': 22.28044633996593...  22.280446  114.184533
# 3  [{'label': 'display', 'lat': 22.27998735323213...  22.279987  114.183274
# 4  [{'label': 'display', 'lat': 22.27903620193624...  22.279036  114.186185
# 5  [{'label': 'display', 'lat': 22.27845403075323...  22.278454  114.183016
# 6  [{'label': 'display', 'lat': 22.27868758664863...  22.278688  114.182610
# 7  [{'label': 'display', 'lat': 22.27871387577066...  22.278714  114.182410
# 8  [{'label': 'display', 'lat': 22.28056227530503...  22.280562  114.183339
# 9  [{'label': 'display', 'lat': 22.27843669927438...  22.278437  114.183919
#
#    neighborhood state                        id
# 0           NaN   NaN  4ff44a45f31c307dc1999e9f
# 1  Causeway Bay   NaN  4ec460866c254debead58565
# 2           NaN   NaN  4d13669f9844b60ce371c2d4
# 3           NaN   NaN  4dfc4e0eae6033b2a4743cfa
# 4  Causeway Bay   NaN  4b3dd9a2f964a520129725e3
# 5  Causeway Bay   NaN  4b1269b5f964a520b28923e3
# 6           NaN   NaN  4b2f15e3f964a52075e924e3
# 7           NaN   NaN  4b14dd56f964a5201ea723e3
# 8           NaN   NaN  4b3ee7edf964a5200ca325e3
# 9           NaN   NaN  50545f8ee4b0f42fb69d529b

# %%
#Mapping the FourSquare categories into preferred grouping for tourist
df_group = dataframe_filtered.copy()
conditions = [
    (df_group['categories'].str.contains("Restaurant|Bar|Dessert|Noodle|Coffee|Bakery|Buffet|Pizza|Cha|Snack")),
    (df_group['categories'].str.contains("Shop|Mall|Store|store")),
    (df_group['categories'].str.contains("Supermarket")),
    (df_group['categories'].str.contains("Hotel|Hostel")),
    (df_group['categories'].str.contains("Club|Yoga|Gym"))]
choices = ['Restaurants', 'Shops', 'Supermarket', 'Hotels', 'Entertainment']
df_group['grouping'] = np.select(conditions, choices, default='Others')
df_group.head(10)
# Out:
#                               name            categories  \
# 0          Eslite Bookstore (誠品書店)             Bookstore
# 1               Apple Causeway Bay     Electronics Store
# 2            SOGO Freshmart (崇光超市)           Supermarket
# 3    Kozy Okonomi-yaki Teppan-yaki   Japanese Restaurant
# 4               Din Tai Fung (鼎泰豐)   Dumpling Restaurant
# 5                     UNIQLO (優衣庫)        Clothing Store
# 6                        Pure Yoga           Yoga Studio
# 7                    Café Corridor                  Café
# 8  Yee Shun Dairy Company (義順牛奶公司)        Cha Chaan Teng
# 9                     Pure Fitness  Gym / Fitness Center
#
#                                        address  cc city country crossStreet  \
# 0         8-10/F, Hysan Place, 500 Hennessy Rd  HK  铜锣湾      香港         NaN
# 1                       銅鑼灣軒尼詩道500號, 希慎廣場, 灣仔區  HK  铜锣湾      香港         NaN
# 2                  B2/F, Sogo, 555 Hennessy Rd  HK  铜锣湾      香港         NaN
# 3           9/F, Circle Plaza, 499 Hennessy Rd  HK  铜锣湾      香港         NaN
# 4                                 68 Yee Wo St  HK  铜锣湾      香港         NaN
# 5  B2/F-G/F, Lee Theatre Plaza, 99 Percival St  HK  铜锣湾      香港         NaN
# 6         25/F, Soundwill Plaza, 38 Russell St  HK  铜锣湾      香港         NaN
# 7                          G/F, 26A Russell St  HK  铜锣湾      香港         NaN
# 8                              506 Lockhart Rd  HK  铜锣湾      香港         NaN
# 9      15/F, Lee Theatre Plaza, 99 Percival St  HK  铜锣湾      香港         NaN
#
#    distance                                   formattedAddress  \
# 0        48         [8-10/F, Hysan Place, 500 Hennessy Rd, 香港]
# 1         7                       [銅鑼灣軒尼詩道500號, 希慎廣場, 灣仔區, 香港]
# 2       104                  [B2/F, Sogo, 555 Hennessy Rd, 香港]
# 3        56           [9/F, Circle Plaza, 499 Hennessy Rd, 香港]
# 4       261                                 [68 Yee Wo St, 香港]
# 5       170  [B2/F-G/F, Lee Theatre Plaza, 99 Percival St, 香港]
# 6       174         [25/F, Soundwill Plaza, 38 Russell St, 香港]
# 7       187                          [G/F, 26A Russell St, 香港]
# 8        95                              [506 Lockhart Rd, 香港]
# 9       153      [15/F, Lee Theatre Plaza, 99 Percival St, 香港]
#
#                                       labeledLatLngs        lat         lng  \
# 0  [{'label': 'display', 'lat': 22.28024004574223...  22.280240  114.183854
# 1  [{'label': 'display', 'lat': 22.2797509, 'lng'...  22.279751  114.183808
# 2  [{'label': 'display', 'lat': 22.28044633996593...  22.280446  114.184533
# 3  [{'label': 'display', 'lat': 22.27998735323213...  22.279987  114.183274
# 4  [{'label': 'display', 'lat': 22.27903620193624...  22.279036  114.186185
# 5  [{'label': 'display', 'lat': 22.27845403075323...  22.278454  114.183016
# 6  [{'label': 'display', 'lat': 22.27868758664863...  22.278688  114.182610
# 7  [{'label': 'display', 'lat': 22.27871387577066...  22.278714  114.182410
# 8  [{'label': 'display', 'lat': 22.28056227530503...  22.280562  114.183339
# 9  [{'label': 'display', 'lat': 22.27843669927438...  22.278437  114.183919
#
#    neighborhood state                        id       grouping
# 0           NaN   NaN  4ff44a45f31c307dc1999e9f          Shops
# 1  Causeway Bay   NaN  4ec460866c254debead58565          Shops
# 2           NaN   NaN  4d13669f9844b60ce371c2d4    Supermarket
# 3           NaN   NaN  4dfc4e0eae6033b2a4743cfa    Restaurants
# 4  Causeway Bay   NaN  4b3dd9a2f964a520129725e3    Restaurants
# 5  Causeway Bay   NaN  4b1269b5f964a520b28923e3          Shops
# 6           NaN   NaN  4b2f15e3f964a52075e924e3  Entertainment
# 7           NaN   NaN  4b14dd56f964a5201ea723e3         Others
# 8           NaN   NaN  4b3ee7edf964a5200ca325e3    Restaurants
# 9           NaN   NaN  50545f8ee4b0f42fb69d529b  Entertainment

# %%
#Summarize the categories for the location
df_grouping = df_group.groupby( ["grouping"] ).count()
df_grouping['categories']
# Out:
# grouping
# Entertainment     4
# Hotels            4
# Others            5
# Restaurants      66
# Shops            19
# Supermarket       2
# Name: categories, dtype: int64

# %%
#Define a new function to iterate to explore the nearby location using FourSquare API
def exploreNearbyVenues(names, latitudes, longitudes):
    try:
        df_output = pd.DataFrame(columns=['Name', 'Entertainment', 'Hotels', 'Restaurants','Shops','Supermarket'])
        for name, lat, lng in zip(names, latitudes, longitudes):

            # create the API request URL
            url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, radius, LIMIT)

            # make the GET request
            results = requests.get(url).json()
            items = results['response']['groups'][0]['items']
            
            dataframe = json_normalize(items) # flatten JSON

            # filter columns
            filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
            dataframe_filtered = dataframe.loc[:, filtered_columns]

            # filter the category for each row
            dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

            # clean columns
            dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]
            
            df_group = dataframe_filtered.copy()
            conditions = [
                (df_group['categories'].str.contains("Restaurant|Bar|Dessert|Noodle|Coffee|Bakery|Buffet|Pizza|Cha|Snack")),
                (df_group['categories'].str.contains("Shop|Mall|Store|store")),
                (df_group['categories'].str.contains("Supermarket")),
                (df_group['categories'].str.contains("Hotel|Hostel")),
                (df_group['categories'].str.contains("Club|Yoga|Gym"))]
            choices = ['Restaurants', 'Shops', 'Supermarket', 'Hotels', 'Entertainment']
            df_group['grouping'] = np.select(conditions, choices, default='Others')
            df_grouping = df_group.groupby( ["grouping"] ).count()
            
            #Ensure there is a value in Entertainment
            try:
                entertain_test = df_grouping['categories']['Entertainment']
            except:
                entertain_test = 0
            
            #Ensure there is a value in Supermarket
            try:
                supermarket_test = df_grouping['categories']['Supermarket']
            except:
                supermarket_test = 0

            #Ensure there is a value in Shops
            try:
                shop_test = df_grouping['categories']['Shops']
            except:
                shop_test = 0

            #Ensure there is a value in Hotels
            try:
                hotel_test = df_grouping['categories']['Hotels']
            except:
                hotel_test = 0
                
            #Ensure there is a value in Restaurants
            try:
                restaurant_test = df_grouping['categories']['Restaurants']
            except:
                restaurant_test = 0
                
            #Iterate to append data to the dataframe
            df_output.loc[(len(df_output))] = [name, entertain_test, hotel_test, restaurant_test, shop_test, supermarket_test]
    
    except:
        print(name)
        print(url)
        print(df_grouping['categories'])
        print(df_output)

    return(df_output)

#Using the clinic data to explore nearby locations
df_nearby = exploreNearbyVenues(df_clinic['Name of Clinic'], df_clinic['Latitude'], df_clinic['Longitude'])
df_nearby
# Out:
#                                                  Name Entertainment Hotels  \
# 0                    Assemblies of God Medical Clinic             0      1
# 1                          BOCHK Health Care Division            10      7
# 2                         Caritas Clinic – Caine Road             8      2
# 3                       Caritas Clinic – Ngau Tau Kok             0      1
# 4                Caritas Jockey Club Tsuen Wan Clinic             0      2
# 5                      Centre of Wellness (Kwun Tong)             2      2
# 6                              Chee Kwong Free Clinic             0      1
# 7                            Ching Chung No. 2 Clinic             0      0
# 8      Christian Family Service Centre Medical Clinic             2      1
# 9                   Clinic of China Resources Company             4      4
# 10                           Emmanuel Medical Mission             0      3
# 11  Fung Kai Public School – Fung Kai Care & Atten...             1      0
# 12                HAECO Medical Clinic (Chek Lap Kok)             0      0
# 13                         HAECO Medical Clinic (TKO)             0      0
# 14             Haven of Hope Bradbury King Lam Clinic             0      0
# 15          Haven of Hope Causeway Bay Medical Centre             4      5
# 16              Haven of Hope S K Yee Hang Hau Clinic             0      0
# 17               Haven of Hope S K Yee Hau Tak Clinic             0      0
# 18                Haven of Hope S K Yee Po Lam Clinic             1      0
# 19                  Haven of Hope Sau Mau Ping Clinic             0      0
# 20  HKFTU Medical & Healthcare Centre (Causeway Ba...             4      4
# 21  HKFTU Medical & Healthcare Centre (Central Cli...             4      2
# 22  Hong Kong Breast Cancer Foundation Breast Heal...             2      8
# 23  Hong Kong Breast Cancer Foundation, Breast Hea...             1      1
# 24  Hong Kong Chiu Chow Merchants Mutual Assistanc...             2      1
df_nearby['Score'] = df_nearby['Entertainment'] * weight_entertain + df_nearby['Hotels'] * weight_hotel + df_nearby['Restaurants'] * weight_restaurant + df_nearby['Shops'] * weight_shops + df_nearby['Supermarket'] * weight_supermarket
df_nearby = df_nearby.sort_values(by=['Score'], ascending=False)
df_nearby
# Out:
#                                                  Name Entertainment Hotels  \
# 58                   The Islamic Union Medical Clinic             4      4
# 67               Chung Sing Benevolent Society Clinic             4      3
# 31         Hong Kong Red Swastika Society Free Clinic             2      6
# 22  Hong Kong Breast Cancer Foundation Breast Heal...             2      8
# 20  HKFTU Medical & Healthcare Centre (Causeway Ba...             4      4
# 66  University Health Service, The Hong Kong Polyt...             0     12
# 9                   Clinic of China Resources Company             4      4
# 15          Haven of Hope Causeway Bay Medical Centre             4      5
# 45  Po Leung Kuk Making Life Beautiful Integrated ...             2      6
# 34                   Hong Kong Workers' Health Centre             0     12
# 36         Kiangsu Chekiang & Shanghai Medical Centre             3      5
# 77    Kwok's Clansmen Association Living Water Clinic             1      8
# 27  Hong Kong Federation of Trade Unions Workers' ...             1      5
# 25  Hong Kong Christian Service, Medical & Dental ...             0     10
# 38                              Lung Hing Tong Clinic             1      4
# 68  Clinic of the Association of the Natives of Tu...             1      8
# 59  The Lok Sin Tong Chan Cho Chak Polyclinics, Mo...             1      5
# 35  Hongkong & Kowloon Senior Citizens' Welfare As...             1      7
# 69  Hong Kong & Kowloon Inhabitants' Main Associat...             2      6
# 46         Po Leung Kuk No.1 Integrated Health Centre             1      3
# 75                            Kin Hong Medical Clinic             1      5
# 55  The Family Planning Association of Hong Kong –...             1      7
# 80                                   Shing Yan Clinic             0     11
# 53  The Family Planning Association of Hong Kong –...             1      6
# 48                               SARDA Wanchai Clinic             1      6
# 65                           UCN Jordan Health Centre             0     10
# 33             Hong Kong Tak Kow Chi Cheng Kok Clinic             3      3
# 2                         Caritas Clinic – Caine Road             8      2
# 24  Hong Kong Chiu Chow Merchants Mutual Assistanc...             2      1
# 71                   Hong Kong Baptist Mission Clinic             0      1
# 4                Caritas Jockey Club Tsuen Wan Clinic             0      2
# 73                   Hong Kong Baptist Mission Clinic             0      2
# 79                              Po Chai Church Clinic             3      2
# 10                           Emmanuel Medical Mission             0      3
# 40  Medical Clinic of the Lok Sin Tong Benevolent ...             0      2
# 21  HKFTU Medical & Healthcare Centre (Central Cli...             4      2
# 51  The Family Planning Association of Hong Kong –...             0      3
# 42                               Peace Medical Centre             1      1
# 52  The Family Planning Association of Hong Kong –...             0      2
# 83                             Wood Man Church Clinic             0      2
# 29  Hong Kong Federation of Trade Unions Workers' ...             0      2
# 47                                   Saint Yen Clinic             0      1
# 57  The Hong Kong and China Gas Company Limited Cl...             5      1
# 72                   Hong Kong Baptist Mission Clinic             1      2
# 26  Hong Kong Federation of Trade Unions Workers' ...             2      1
# 70                   Hong Kong Baptist Mission Clinic             2      1
# 84                                      Yee On Clinic             3      4
# 3                       Caritas Clinic – Ngau Tau Kok             0      1
# 8      Christian Family Service Centre Medical Clinic             2      1
# 83          62     2           1   201
# 29          58    12           1   199
# 47          62     8           0   199
# 57          59     8           1   198
# 72          59     5           1   196
# 26          57    12           2   196
# 70          57     8           1   189
# 84          54     4           0   189
# 3           55    11           1   184
# 8           53    14           1   183
# 5           53     8           1   182
# 1           41     9           1   180
# 6           42    13           1   147
# 62          40    12           1   147
# 76          42     7           0   143
# 17          41    17           1   143
# 56          42     4           0   131
# 54          38     6           1   128
# 81          39     6           1   127
# 28          39     6           1   127
# 82          38     5           1   127
# 37          36    11           1   124
# 14          35    16           1   124
# 64          31     9           1   106
# 30          31     7           1   103
# 63          30     5           2   101
# 49          28     4           0    93
# 43          26     6           0    89
# 0           26     4           0    87
# 16          25     7           0    82
# 32          24     3           0    80
# 23          21     6           0    75
# 50          21     3           0    67
# 44          20     4           0    65
# 78          20     4           0    64
# 41          20     3           0    63
# 7           16     6           0    54
# 61          12     4           1    48
# 18          10    10           1    44
# 60          13     5           0    44
# 39           9     0           0    27
# 11           8     1           0    26
# 19           3     5           0    14
# 13           1     1           0     4
# 74           0     2           0     2
# 12           0     0           0     0

# %%
#Select the top 5 clinics for visualization
Top5 = [58,67,31,22,20]

df_clinic_top5 = pd.DataFrame()

for num in Top5:
    df_clinic_top5 = df_clinic_top5.append(df_clinic.loc[num])

# %%
df_clinic_top5
# Out:
#                                               Address  Cluster   Latitude  \
# 58          7/F, 40 Oi Kwan Road, Wan Chai, Hong Kong      2.0  22.277426
# 67  Flat C, 1/F, 379 Lockhart Road, Wan Chai, Hong...      2.0  22.279655
# 31  Western Clinic, No. 25 Dragon Road, Causeway B...      2.0  22.282038
# 22  21/F, Jupiter Tower, 9 Jupiter Street, North P...      2.0  22.286840
# 20  Western Medicine Clinic, 1/F, 5-13 Lee Garden ...      2.0  22.280885
#
#      Longitude                                     Name of Clinic
# 58  114.178773                   The Islamic Union Medical Clinic
# 67  114.179681               Chung Sing Benevolent Society Clinic
# 31  114.193087         Hong Kong Red Swastika Society Free Clinic
# 22  114.192188  Hong Kong Breast Cancer Foundation Breast Heal...
# 20  114.182659  HKFTU Medical & Healthcare Centre (Causeway Ba...

# %%
# create Top 5 map
clinic_map_top5 = folium.Map(location=[latitude, longitude], zoom_start=15)

for lat, long, clinic_name in zip(df_clinic_top5['Latitude'], df_clinic_top5['Longitude'], df_clinic_top5['Name of Clinic']):
    label = folium.Popup(clinic_name, parse_html=True)
    folium.CircleMarker(
        [lat, long],
        radius=10,
        popup=label,
        color='green',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(clinic_map_top5)  

clinic_map_top5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# For easier reading, a generated map image is used for illustration
#
# Conclusion
# The top 5 clinics are located in the center of the Hong Kong Island which are good recommendations for the tourists in China to stay in Hong Kong. If we go back to the clustering in first map, all 5 clinics are located in the red cluster.
# This notebook is useful because tourists will not be familiar with the useful spots in Hong Kong, e.g. Hotels and restaurants. If they are keen to visit Hong Kong for medication, the recommended clinics will be suitable for their stays.
